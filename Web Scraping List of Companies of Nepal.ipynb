# %%
from bs4 import BeautifulSoup
import requests
url = 'https://en.wikipedia.org/wiki/List_of_companies_of_Nepal'
page = requests.get(url)
soup = BeautifulSoup(page.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of companies of Nepal - Wikipedia</title>
# ...

# %%
soup.find('table')
# Out:
# <table class="wikitable sortable">
# <caption>Notable companies <br/>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9f9f9; color:#f9f9f9;">    </span> Active</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9e6ff; color:#f9e6ff;">    </span> State-owned</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#dddddd; color:#dddddd;">    </span> Defunct</span>
# </caption>
# <tbody><tr>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Sector
# </th>
# <th>Headquarters
# </th>
# <th>Founded
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr style="background:#dddddd;">
# <td><a href="/wiki/Agni_Air" title="Agni Air">Agni Air</a>
# </td>
# <td>Consumer services
# </td>
# <td>Airlines
# </td>
# <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
# </td>
# <td>2006
# </td>
# <td>Airline, defunct 2006
# </td></tr>
# ...

# %%
#table_class = soup.table
#table_class
# Out:
# <table class="wikitable sortable">
# <caption>Notable companies <br/>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9f9f9; color:#f9f9f9;">    </span> Active</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9e6ff; color:#f9e6ff;">    </span> State-owned</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#dddddd; color:#dddddd;">    </span> Defunct</span>
# </caption>
# <tbody><tr>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Sector
# </th>
# <th>Headquarters
# </th>
# <th>Founded
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr style="background:#dddddd;">
# <td><a href="/wiki/Agni_Air" title="Agni Air">Agni Air</a>
# </td>
# <td>Consumer services
# </td>
# <td>Airlines
# </td>
# <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
# </td>
# <td>2006
# </td>
# <td>Airline, defunct 2006
# </td></tr>
# ...

# %%
table_class.find_all('tr')
# Out:
# [<tr>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Sector
#  </th>
#  <th>Headquarters
#  </th>
#  <th>Founded
#  </th>
#  <th class="unsortable">Notes
#  </th></tr>,
#  <tr style="background:#dddddd;">
#  <td><a href="/wiki/Agni_Air" title="Agni Air">Agni Air</a>
#  </td>
#  <td>Consumer services
#  </td>
#  <td>Airlines
#  </td>
#  <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
#  </td>
#  <td>2006
#  </td>
#  <td>Airline, defunct 2006
#  </td></tr>,
#  <tr style="background:#f9e6ff;">
#  <td><a href="/wiki/Agriculture_Development_Bank" title="Agriculture Development Bank">Agriculture Development Bank</a>
#  </td>
#  <td>Financials
#  </td>
#  <td>Banks
#  </td>
#  <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
#  </td>
#  <td>1968
#  </td>
#  <td>Bank, rural credit institution
#  </td></tr>,
#  <tr style="background:#dddddd;">
#  <td><a href="/wiki/Air_Nepal_International" title="Air Nepal International">Air Nepal International</a>
#  </td>
# ...

# %%
#tags = table_class.find_all('tr')
#tags
# Out:
# [<tr>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Sector
#  </th>
#  <th>Headquarters
#  </th>
#  <th>Founded
#  </th>
#  <th class="unsortable">Notes
#  </th></tr>,
#  <tr style="background:#dddddd;">
#  <td><a href="/wiki/Agni_Air" title="Agni Air">Agni Air</a>
#  </td>
#  <td>Consumer services
#  </td>
#  <td>Airlines
#  </td>
#  <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
#  </td>
#  <td>2006
#  </td>
#  <td>Airline, defunct 2006
#  </td></tr>,
#  <tr style="background:#f9e6ff;">
#  <td><a href="/wiki/Agriculture_Development_Bank" title="Agriculture Development Bank">Agriculture Development Bank</a>
#  </td>
#  <td>Financials
#  </td>
#  <td>Banks
#  </td>
#  <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
#  </td>
#  <td>1968
#  </td>
#  <td>Bank, rural credit institution
#  </td></tr>,
#  <tr style="background:#dddddd;">
#  <td><a href="/wiki/Air_Nepal_International" title="Air Nepal International">Air Nepal International</a>
#  </td>
# ...

# %%
soup.find_all('table')[0]
# Out:
# <table class="wikitable sortable">
# <caption>Notable companies <br/>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9f9f9; color:#f9f9f9;">    </span> Active</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9e6ff; color:#f9e6ff;">    </span> State-owned</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#dddddd; color:#dddddd;">    </span> Defunct</span>
# </caption>
# <tbody><tr>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Sector
# </th>
# <th>Headquarters
# </th>
# <th>Founded
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr style="background:#dddddd;">
# <td><a href="/wiki/Agni_Air" title="Agni Air">Agni Air</a>
# </td>
# <td>Consumer services
# </td>
# <td>Airlines
# </td>
# <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
# </td>
# <td>2006
# </td>
# <td>Airline, defunct 2006
# </td></tr>
# ...

# %%
#soup.find('table',class_ = 'wikitable sortable') # yesari pani garna sakeyo
# Out:
# <table class="wikitable sortable">
# <caption>Notable companies <br/>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9f9f9; color:#f9f9f9;">    </span> Active</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9e6ff; color:#f9e6ff;">    </span> State-owned</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#dddddd; color:#dddddd;">    </span> Defunct</span>
# </caption>
# <tbody><tr>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Sector
# </th>
# <th>Headquarters
# </th>
# <th>Founded
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr style="background:#dddddd;">
# <td><a href="/wiki/Agni_Air" title="Agni Air">Agni Air</a>
# </td>
# <td>Consumer services
# </td>
# <td>Airlines
# </td>
# <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
# </td>
# <td>2006
# </td>
# <td>Airline, defunct 2006
# </td></tr>
# ...

# %%
#table = soup.find_all("table")[0] # hami lai chaheyiko mian yo table ho 
#table
# Out:
# <table class="wikitable sortable">
# <caption>Notable companies <br/>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9f9f9; color:#f9f9f9;">    </span> Active</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9e6ff; color:#f9e6ff;">    </span> State-owned</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#dddddd; color:#dddddd;">    </span> Defunct</span>
# </caption>
# <tbody><tr>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Sector
# </th>
# <th>Headquarters
# </th>
# <th>Founded
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr style="background:#dddddd;">
# <td><a href="/wiki/Agni_Air" title="Agni Air">Agni Air</a>
# </td>
# <td>Consumer services
# </td>
# <td>Airlines
# </td>
# <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
# </td>
# <td>2006
# </td>
# <td>Airline, defunct 2006
# </td></tr>
# ...

# %%
soup.find_all('th') # table ko name matra get garna yesto harni
# Out:
# [<th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Sector
#  </th>,
#  <th>Headquarters
#  </th>,
#  <th>Founded
#  </th>,
#  <th class="unsortable">Notes
#  </th>,
# ...

# %%
world_titles = soup.find_all('th') # yesto garni pani vayo (yesto garni yo ramro data dinxa)
world_titles
# jo hami le yo soup.find_all garika xau ni yesto garda k hunxa vani second table haru ko pani name lai print garxa soo yadi hami lai first table matra title haru print garnu xa vaniu yesto garni
# Out:
# [<th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Sector
#  </th>,
#  <th>Headquarters
#  </th>,
#  <th>Founded
#  </th>,
#  <th class="unsortable">Notes
#  </th>,
# ...

# %%
world_titles = table.find_all('th') # yesto garni first table ko matra titles haru get garna (but soup.find_all vanira lekheu vani second table bata ko titles haru pani print hunxa)
world_titles
# Out:
# [<th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Sector
#  </th>,
#  <th>Headquarters
#  </th>,
#  <th>Founded
#  </th>,
#  <th class="unsortable">Notes
#  </th>]

# %%
world_table_titles = [title.text for title in world_titles] # yo k gariko vani loop lagako hau i.e first ma rank ma loop lagxa ani name .... soo on )
world_table_titles  # ho yesari clear vayira aauxa only tavle ko title matra aauxa
# Out:
# ['Name\n', 'Industry\n', 'Sector\n', 'Headquarters\n', 'Founded\n', 'Notes\n']

# %%
world_table_titles = [title.text.strip() for title in world_titles] # yo k gariko vani loop lagako hau i.e first ma rank ma loop lagxa ani name .... soo on )
world_table_titles  # ho yesari clear vayira aauxa only tavle ko title matra aauxa
# Out:
# ['Name', 'Industry', 'Sector', 'Headquarters', 'Founded', 'Notes']

# %%
import pandas as pd 
df = pd.DataFrame(columns = world_table_titles)
df # yo samma hami le table ko title haru matra print gareu
# Out:
# Empty DataFrame
# Columns: [Name, Industry, Sector, Headquarters, Founded, Notes]
# Index: []

# %%
world_titles = table.find_all('tr') # aaba yo bata hami table ma vayika data haru get gardai xau 
world_titles
# Out:
# [<tr>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Sector
#  </th>
#  <th>Headquarters
#  </th>
#  <th>Founded
#  </th>
#  <th class="unsortable">Notes
#  </th></tr>,
#  <tr style="background:#dddddd;">
#  <td><a href="/wiki/Agni_Air" title="Agni Air">Agni Air</a>
#  </td>
#  <td>Consumer services
#  </td>
#  <td>Airlines
#  </td>
#  <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
#  </td>
#  <td>2006
#  </td>
#  <td>Airline, defunct 2006
#  </td></tr>,
#  <tr style="background:#f9e6ff;">
#  <td><a href="/wiki/Agriculture_Development_Bank" title="Agriculture Development Bank">Agriculture Development Bank</a>
#  </td>
#  <td>Financials
#  </td>
#  <td>Banks
#  </td>
#  <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
#  </td>
#  <td>1968
#  </td>
#  <td>Bank, rural credit institution
#  </td></tr>,
#  <tr style="background:#dddddd;">
#  <td><a href="/wiki/Air_Nepal_International" title="Air Nepal International">Air Nepal International</a>
#  </td>
# ...

# %%
column_data = table.find_all('tr') # yo pani same hio mathi ka deutai jasto (eni haru madthey ek matra lekhda pani hunxa )
column_data
# Out:
# [<tr>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Sector
#  </th>
#  <th>Headquarters
#  </th>
#  <th>Founded
#  </th>
#  <th class="unsortable">Notes
#  </th></tr>,
#  <tr style="background:#dddddd;">
#  <td><a href="/wiki/Agni_Air" title="Agni Air">Agni Air</a>
#  </td>
#  <td>Consumer services
#  </td>
#  <td>Airlines
#  </td>
#  <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
#  </td>
#  <td>2006
#  </td>
#  <td>Airline, defunct 2006
#  </td></tr>,
#  <tr style="background:#f9e6ff;">
#  <td><a href="/wiki/Agriculture_Development_Bank" title="Agriculture Development Bank">Agriculture Development Bank</a>
#  </td>
#  <td>Financials
#  </td>
#  <td>Banks
#  </td>
#  <td><a href="/wiki/Kathmandu" title="Kathmandu">Kathmandu</a>
#  </td>
#  <td>1968
#  </td>
#  <td>Bank, rural credit institution
#  </td></tr>,
#  <tr style="background:#dddddd;">
#  <td><a href="/wiki/Air_Nepal_International" title="Air Nepal International">Air Nepal International</a>
#  </td>
# ...

# %%
column_data = table.find_all('tr')

# %%
for row in column_data:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    print(individual_row_data)
  #yesari loop lagayira print garyo vani sabpai data yesari dinxa but next way tala xa
# Out:
# []
# ['Agni Air', 'Consumer services', 'Airlines', 'Kathmandu', '2006', 'Airline, defunct 2006']
# ['Agriculture Development Bank', 'Financials', 'Banks', 'Kathmandu', '1968', 'Bank, rural credit institution']
# ['Air Nepal International', 'Consumer services', 'Airlines', 'Kathmandu', '2005', 'Airline, defunct 2006']
# ['Asian Airlines', 'Consumer services', 'Airlines', 'Kathmandu', '2002[6]', 'Airline, defunct 2006']
# ['Bajeko Sekuwa', 'Consumer services', 'Restaurants & bars', 'Kathmandu', '?', 'Restaurant chain']
# ['Base Air', 'Consumer services', 'Airlines', '?', '2004', 'Airline, defunct 2007']
# ['Bhatbhateni supermarket', 'Consumer services', 'Retail Chain', 'Kathmandu', '1984', '']
# ['Buddha Air', 'Consumer services', 'Airlines', 'Jawalakhel', '1997', 'Domestic airline']
# ['Chaudhary Group', 'Conglomerates', '-', 'Kathmandu', '1968', 'Consumer goods, financials, industrials']
# ['Cosmic Air', 'Consumer services', 'Airlines', 'Kathmandu', '1997', 'Airline, defunct 2008']
# ...

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    print(individual_row_data)
    
  # yo first ko [] yesto wala xa ni mathi tislai remove garna yesto garnu parxa
# Out:
# ['Agni Air', 'Consumer services', 'Airlines', 'Kathmandu', '2006', 'Airline, defunct 2006']
# ['Agriculture Development Bank', 'Financials', 'Banks', 'Kathmandu', '1968', 'Bank, rural credit institution']
# ['Air Nepal International', 'Consumer services', 'Airlines', 'Kathmandu', '2005', 'Airline, defunct 2006']
# ['Asian Airlines', 'Consumer services', 'Airlines', 'Kathmandu', '2002[6]', 'Airline, defunct 2006']
# ['Bajeko Sekuwa', 'Consumer services', 'Restaurants & bars', 'Kathmandu', '?', 'Restaurant chain']
# ['Base Air', 'Consumer services', 'Airlines', '?', '2004', 'Airline, defunct 2007']
# ['Bhatbhateni supermarket', 'Consumer services', 'Retail Chain', 'Kathmandu', '1984', '']
# ['Buddha Air', 'Consumer services', 'Airlines', 'Jawalakhel', '1997', 'Domestic airline']
# ['Chaudhary Group', 'Conglomerates', '-', 'Kathmandu', '1968', 'Consumer goods, financials, industrials']
# ['Cosmic Air', 'Consumer services', 'Airlines', 'Kathmandu', '1997', 'Airline, defunct 2008']
# ...

# %%
for row in column_data:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
print(individual_row_data) # yesari print gareu vani single column ko data dinxa 
    
#  (random data deni raixa yesari jun sukai column ko pani dena sakni  raixa )
# Out:
# ['Yeti Airlines', 'Consumer services', 'Airlines', 'Kathmandu', '1998', 'Airline']

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df) # pandas use gariko 
    df.loc[length] = individual_row_data
df
# Out:
#                              Name            Industry  \
# 0                        Agni Air   Consumer services
# 1    Agriculture Development Bank          Financials
# 2         Air Nepal International   Consumer services
# 3                  Asian Airlines   Consumer services
# 4                   Bajeko Sekuwa   Consumer services
# 5                        Base Air   Consumer services
# 6         Bhatbhateni supermarket   Consumer services
# 7                      Buddha Air   Consumer services
# 8                 Chaudhary Group       Conglomerates
# 9                      Cosmic Air   Consumer services
# 10  Deurali-Janta Pharmaceuticals         Health care
# 11                      Dish Home   Consumer services
# 12                    Everest Air   Consumer services
# 13                       Fly Yeti   Consumer services
# 14         Flying Dragon Airlines   Consumer services
# 15          Giribandhu Tea Estate      Consumer goods
# ...

# %%
pwd
# Out:
# 'C:\\Users\\ASUS'

# %%
df.to_csv(r'C:\\Users\\ASUS\Nepalies_Companies.csv',index = False)
