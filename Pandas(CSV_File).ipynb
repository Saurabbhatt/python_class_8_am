# %%
# CSV(comma-separated value) File
  #Pandas

# %%
#pip install pandas ( install garna lai pandas )

import pandas as pd

# %%
file = open('info.csv','x')
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 file = open('info.csv','x')
#       2 file.close()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'info.csv'

# %%
info = ""
file = open("info.csv","w")
file.write("name,age,add\n")
n = int(input("Enter n = "))
for i in range(n):
    name = input("Enter name = ")
    age = int(input("Enter age = "))
    add = input("Enter add = ")
    info = info + f"{name},{age},{add}\n"

file.write(info)
file.close()
# Out:
# Enter n =  6
# Enter name =  Ram
# Enter age =  30
# Enter add =  DHN
# Enter name =  Hari
# Enter age =  28
# Enter add =  MNR
# Enter name =  Sita
# Enter age =  25
# Enter add =  Pokhara
# Enter name =  Gita
# Enter age =  26
# Enter add =  Jhapa
# Enter name =  Teja
# Enter age =  27
# Enter add =  Mugu
# Enter name =  Tej
# Enter age =  32
# Enter add =  Pokhara

# %%
import pandas as pd
df = pd.read_csv("info.csv")
df
# Out:
#    name  age      add
# 0   Ram   30      DHN
# 1  Hari   28      MNR
# 2  Sita   25  Pokhara
# 3  Gita   26    Jhapa
# 4  Teja   27     Mugu
# 5   Tej   32  Pokhara

# %%
df = pd.read_csv("info.csv")
df.head()  # df.head() yesle mathi bata tala reag or print garxa data lai
# Out:
#    name  age      add
# 0   Ram   30      DHN
# 1  Hari   28      MNR
# 2  Sita   25  Pokhara
# 3  Gita   26    Jhapa
# 4  Teja   27     Mugu

# %%
df = pd.read_csv("info.csv")
df.tail()  # df.tail() vanyo vani tala bata mathi print garxa data lai
# Out:
#    name  age      add
# 1  Hari   28      MNR
# 2  Sita   25  Pokhara
# 3  Gita   26    Jhapa
# 4  Teja   27     Mugu
# 5   Tej   32  Pokhara

# %%
df = pd.read_csv("info.csv",usecols = ["name","add"])
df   # yeasari name ra add lai matra print garna sakinxa(coloum lai print gariko)
# Out:
#    name      add
# 0   Ram      DHN
# 1  Hari      MNR
# 2  Sita  Pokhara
# 3  Gita    Jhapa
# 4  Teja     Mugu
# 5   Tej  Pokhara

# %%
df = pd.read_csv("info.csv")
df
# Out:
#    name  age      add
# 0   Ram   30      DHN
# 1  Hari   28      MNR
# 2  Sita   25  Pokhara
# 3  Gita   26    Jhapa
# 4  Teja   27     Mugu
# 5   Tej   32  Pokhara

# %%
df.iloc[1:5]  # data lai chaheko index aanusar print garna lahi yesto garni
# Out:
#    name  age      add
# 1  Hari   28      MNR
# 2  Sita   25  Pokhara
# 3  Gita   26    Jhapa
# 4  Teja   27     Mugu

# %%
df['add']
# Out:
# 0        DHN
# 1        MNR
# 2    Pokhara
# 3      Jhapa
# 4       Mugu
# 5    Pokhara
# Name: add, dtype: object

# %%
df['add']=='Pokhara'
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# Name: add, dtype: bool

# %%
df[df['add']=='Pokhara']
# Out:
#    name  age      add
# 2  Sita   25  Pokhara
# 5   Tej   32  Pokhara

# %%
df[(df['add']=='Pokhara') & (df['age'] >=25)] # yo chai and (&) use garira banako
# Out:
#    name  age      add
# 2  Sita   25  Pokhara
# 5   Tej   32  Pokhara

# %%
df[(df['add']=='Pokhara') | (df['age'] >=25)]  # yo chai or(|) use garira banako
# Out:
#    name  age      add
# 0   Ram   30      DHN
# 1  Hari   28      MNR
# 2  Sita   25  Pokhara
# 3  Gita   26    Jhapa
# 4  Teja   27     Mugu
# 5   Tej   32  Pokhara

# %%
df = pd.read_csv("info.csv")
df['sn'] = [i for i in range(1,7)]
df
# Out:
#    name  age      add  sn
# 0   Ram   30      DHN   1
# 1  Hari   28      MNR   2
# 2  Sita   25  Pokhara   3
# 3  Gita   26    Jhapa   4
# 4  Teja   27     Mugu   5
# 5   Tej   32  Pokhara   6

# %%
data = {'sn':[7,8],'age':[20,25],'name':['Tej','Hari'],'add':['Dhangadhi','Kathmandu']}
data
# Out:
# {'sn': [7, 8],
#  'age': [20, 25],
#  'name': ['Tej', 'Hari'],
#  'add': ['Dhangadhi', 'Kathmandu']}

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#    sn  age  name        add
# 0   7   20   Tej  Dhangadhi
# 1   8   25  Hari  Kathmandu

# %%
df = pd.concat([df,df1])
df
# Out:
#    name  age        add  sn
# 0   Ram   30        DHN   1
# 1  Hari   28        MNR   2
# 2  Sita   25    Pokhara   3
# 3  Gita   26      Jhapa   4
# 4  Teja   27       Mugu   5
# 5   Tej   32    Pokhara   6
# 0   Tej   20  Dhangadhi   7
# 1  Hari   25  Kathmandu   8

# %%
df.csv('new_data.csv')

# %%
df = pd.read_csv('new_data.csv',usecols = ['sn','name','age','add'],index_col = 'sn')
df

# %%
df.drop([3,4], axis = 0)
# Out:
#    name  age        add  sn
# 0   Ram   30        DHN   1
# 1  Hari   28        MNR   2
# 2  Sita   25    Pokhara   3
# 5   Tej   32    Pokhara   6
# 0   Tej   20  Dhangadhi   7
# 1  Hari   25  Kathmandu   8

# %%
df.drop(['age'], axis = 1)
# Out:
#    name        add  sn
# 0   Ram        DHN   1
# 1  Hari        MNR   2
# 2  Sita    Pokhara   3
# 3  Gita      Jhapa   4
# 4  Teja       Mugu   5
# 5   Tej    Pokhara   6
# 0   Tej  Dhangadhi   7
# 1  Hari  Kathmandu   8

# %%
pwd
# Out:
# 'C:\\Users\\ASUS'
